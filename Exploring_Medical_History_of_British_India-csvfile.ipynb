# %%
import pandas as pd

# %%
df = pd.read_csv('nls-text-indiaPapers/indiaPapers-inventory.csv', header=None, names=['fileid', 'title'])
df.head()
# Out:
#          fileid                                              title
# 0  74457530.txt  Distribution and causation of leprosy in Briti...
# 1  74457800.txt  Report of an outbreak of cholera in Suhutwar, ...
# 2  74458285.txt  Report of an investigation into the causes of ...
# 3  74458388.txt  Account of plague administration in the Bombay...
# 4  74458575.txt  Inquiry into the circumstances attending an ou...

# %%
df.count()
# Out:
# fileid    468
# title     468
# dtype: int64

# %%
df[0:50]
# Out:
#           fileid                                              title
# 0   74457530.txt  Distribution and causation of leprosy in Briti...
# 1   74457800.txt  Report of an outbreak of cholera in Suhutwar, ...
# 2   74458285.txt  Report of an investigation into the causes of ...
# 3   74458388.txt  Account of plague administration in the Bombay...
# 4   74458575.txt  Inquiry into the circumstances attending an ou...
# 5   74461102.txt         Cholera in India, 1862 to 1881 - IP/6/SB.4
# 6   74461103.txt             Cholera in southern India - IP/25/PI.5
# 7   74462535.txt   Hookworm disease and how to prevent it - IP/QB.9
# 8   74462588.txt  Report by Surgeon-Major Lyons, I.M.S., Preside...
# 9   77504163.txt  Report by Surgeon-Captain Childe, I.M.S. - Par...
# 10  77504164.txt  Summary of work carried on by Mr Hankin - Part...
# 11  74463059.txt  Leprosy and its control in the Bombay Presiden...
# 12  74463060.txt  Leprosy in India: report of the Leprosy Commis...
# ...
