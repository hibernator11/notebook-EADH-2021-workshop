# %% [markdown]
# ## RusAge
# Data from RusAge (https://www.kaggle.com/oldaandozerskaya/fiction-corpus-for-agebased-text-classification)
#
# RusAge: Corpus for Age-Based Text Classification
# Russian fiction books' previews with age rating labels.

# %%
import pandas as pd

# %% [markdown]
# #### Columns in the dataset
#
# - name of the file (books for adults start with 'adults' and children's books start with 'children')
# - book title
# - author
# - age rating according to Russian age rating system
# - genres

# %%
df = pd.read_csv('RusAge.csv', sep=';', names=["filename","book_title","author","age_rating","genres"])
df.head()
# Out:
#          filename                                book_title           author  \
# 0  children_1.txt                              Три четверти  Анна Красильщик
# 1  children_2.txt                        Повести и рассказы   Аркадий Гайдар
# 2  children_3.txt  Оленёнок Крапинка, или Бархатистый носик       Холли Вебб
# 3  children_4.txt                         Сара и роль мечты       Холли Вебб
# 4  children_5.txt         Как Гитлер украл розового кролика      Джудит Керр
#
#    age_rating                       genres
# 0          12  Детская проза|Детские книги
# 1          12  Детская проза|Детские книги
# 2           6  Детская проза|Детские книги
# 3           6  Детская проза|Детские книги
# 4           6  Детская проза|Детские книги

# %%
df.count()
# Out:
# filename      5492
# book_title    5492
# author        5492
# age_rating    5492
# genres        5492
# dtype: int64

# %%
df[0:50]
# Out:
#            filename                                         book_title  \
# 0    children_1.txt                                       Три четверти
# 1    children_2.txt                                 Повести и рассказы
# 2    children_3.txt           Оленёнок Крапинка, или Бархатистый носик
# 3    children_4.txt                                  Сара и роль мечты
# 4    children_5.txt                  Как Гитлер украл розового кролика
# 5    children_6.txt                      Вместе весело шагать. Сборник
# 6    children_7.txt                      В каждом времени – свои герои
# 7    children_8.txt                                             Молния
# 8    children_9.txt                     Школа принцесс. Вот так принц!
# 9   children_10.txt      #ДругЗаДруга. Книга о дружбе животных и людей
# 10  children_11.txt  Как я под партой сидел. Веселые школьные расск...
# 11  children_12.txt                     Рассказы про Россию. 1861—1922
# 12  children_13.txt                       Приключения Трисона в Альпах
# 13  children_14.txt                              Волчье небо. 1944 год
# 14  children_15.txt                   Любопытный воробей и кот Тимофей
# 15  children_16.txt                      Истории для девочек (сборник)
# 16  children_17.txt            Утёнок Счастливчик, или Настоящий герой
# 17  children_18.txt              Овечка Зефирка, или Чудесное спасение
# 18  children_19.txt           Поросёнок Пуговка, или Счастливый случай
# 19  children_20.txt  Гроза двенадцатого года. Рассказы для детей об...
# 20  children_21.txt                          Пассажир последнего рейса
# 21  children_22.txt                           Креативный «пятый альфа»
# 22  children_23.txt                              Сказки снежного ветра
# 23  children_24.txt                            Лама – подружка невесты
# 24  children_25.txt              Мопс, который мечтал стать единорогом
# 25  children_26.txt             Дай лапу! Большая книга добрых историй
# 26  children_27.txt                         Старый дом и его обитатели
# 27  children_28.txt                      Сказ о трех веселых девчонках
# 28  children_29.txt                                    Тигрёнок Васька
# 29  children_30.txt                                    Хитрый бурундук
# 30  children_31.txt                                    Весёлые истории
# 31  children_32.txt                                      Звёздная Река
# 32  children_33.txt                        Когда море стало серебряным
# 33  children_34.txt  КриБ,или Красное и белое в жизни тайного пионе...
# 34  children_35.txt             Большая книга рождественских рассказов
# 35  children_36.txt            Зимние сказки и рождественские предания
# 36  children_37.txt                                 Фото на развалинах
# 37  children_38.txt                           Приключения по контракту
# 38  children_39.txt                                         Литеродура
# 39  children_40.txt                                        Слушай птиц
# 40  children_41.txt                      Про Дуньку, которую знали все
# 41  children_42.txt                                Лягушонок Ливерпуль
# 42  children_43.txt                                            Лёвушка
# 43  children_44.txt                                  Забавные рассказы
# 44  children_45.txt                                    Битвы по средам
# 45  children_46.txt                                 Сказочная суматоха
# 46  children_47.txt                             Чудесный камень Маюрми
# 47  children_48.txt                                        Жизнь Амаль
# 48  children_49.txt  Тридцать три несчастья. Том 4. Занавес опускается
# 49  children_50.txt                                           Лампёшка
#
#                  author  age_rating                       genres
# 0       Анна Красильщик          12  Детская проза|Детские книги
# 1        Аркадий Гайдар          12  Детская проза|Детские книги
# 2            Холли Вебб           6  Детская проза|Детские книги
# 3            Холли Вебб           6  Детская проза|Детские книги
# 4           Джудит Керр           6  Детская проза|Детские книги
# 5     Коллектив авторов           6  Детская проза|Детские книги
# 6     Геннадий Волобуев          12  Детская проза|Детские книги
# 7         Антея Симмонс          12  Детская проза|Детские книги
# 8          Прунелла Бат           6  Детская проза|Детские книги
# 9      Кристина Кретова           6  Детская проза|Детские книги
# 10      Виктор Голявкин          16  Детская проза|Детские книги
# 11    Мариэтта Чудакова          12  Детская проза|Детские книги
# 12     Михаил Самарский          12  Детская проза|Детские книги
# 13        Юлия Яковлева          12  Детская проза|Детские книги
# 14     Михаил Фишельман           6  Детская проза|Детские книги
# 15        Лидия Чарская           6  Детская проза|Детские книги
# 16         Хелен Питерс           6  Детская проза|Детские книги
# 17         Хелен Питерс           6  Детская проза|Детские книги
# 18         Хелен Питерс           6  Детская проза|Детские книги
# 19    Владимир Дмитриев          12  Детская проза|Детские книги
# 20     Роберт Штильмарк          12  Детская проза|Детские книги
# 21         Ирина Асеева           6  Детская проза|Детские книги
# 22           Холли Вебб           6  Детская проза|Детские книги
# 23          Белла Свифт           6  Детская проза|Детские книги
# 24          Белла Свифт           6  Детская проза|Детские книги
# 25           Холли Вебб           6  Детская проза|Детские книги
# 26       Ирина Безуглая          16  Детская проза|Детские книги
# 27       Ирина Безуглая          16  Детская проза|Детские книги
# 28      Ольга Перовская           6  Детская проза|Детские книги
# 29    Геннадий Снегирев           6  Детская проза|Детские книги
# 30    Коллектив авторов           6  Детская проза|Детские книги
# 31            Грейс Лин           6  Детская проза|Детские книги
# 32            Грейс Лин           6  Детская проза|Детские книги
# 33         Марк Олейник          12  Детская проза|Детские книги
# 34      Владимир Зоберн          12  Детская проза|Детские книги
# 35              Сборник           6  Детская проза|Детские книги
# 36  Светлана Пономарева          16  Детская проза|Детские книги
# 37       Михаил Логинов          12  Детская проза|Детские книги
# 38           Юлия Линде          12  Детская проза|Детские книги
# 39    Виктория Лебедева          12  Детская проза|Детские книги
# 40    Надежда Васильева          16  Детская проза|Детские книги
# 41        Лион Измайлов          12  Детская проза|Детские книги
# 42        Анатолий Крым           6  Детская проза|Детские книги
# 43         Татьяна Кюне           6  Детская проза|Детские книги
# 44           Гэри Шмидт          12  Детская проза|Детские книги
# 45        Ольга Гуревич           6  Детская проза|Детские книги
# 46        Дарья Донцова           6  Детская проза|Детские книги
# 47            Аиша Саид          12  Детская проза|Детские книги
# 48        Лемони Сникет          12  Детская проза|Детские книги
# 49           Аннет Схап           6  Детская проза|Детские книги

# %%
df['age_rating'].value_counts().plot(kind='bar')

# %%
df['author'].value_counts().plot(kind='bar', figsize=(25,8))

# %%
df['author'].value_counts()[df['author'].value_counts() > 20].plot(kind='bar', figsize=(20,8))

# %%
df['genres'].value_counts().plot(kind='bar', figsize=(15,8))

# %% [markdown]
# ## References
#
# Sherratt, Tim. (2019, November 17). GLAM-Workbench/csv-explorer (Version v0.1.0). Zenodo. http://doi.org/10.5281/zenodo.3544712
#
# RusAge (https://www.kaggle.com/oldaandozerskaya/fiction-corpus-for-agebased-text-classification)
